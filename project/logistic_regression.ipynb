# %%
import os
import json
import time
import datetime
import requests
import numpy as np
import pandas as pd

from patsy import dmatrices
from collections import defaultdict
from matplotlib import pyplot as plt
from pandas import Series, DataFrame
# %matplotlib inline

import sklearn.metrics as metrics
import sklearn.utils as utils
import sklearn.linear_model as linear_model
import sklearn.cross_validation as cross_validation
from sklearn.preprocessing import StandardScaler

#import statsmodels.api as sm

# %%
dframe = pd.read_csv('filtered_loan_data.csv', index_col='id')

# %%
# to predict default -- filter: paid,defaulted
dframe = dframe[dframe.status != "expired"]
dframe = dframe[dframe.status != "in_repayment"]
dframe = dframe[dframe.status != "refunded"]
# Out:
# defaulted 2372
# paid 82140

# %%
def is_paid(row):
    paid = row.status
    if paid == "paid":
        return 1
    else:
        return 0

dframe['status'] = dframe.apply(is_paid, axis = 1)


for it, dat in dframe.groupby("status"):
    print it, len(dat)
# Out:
# 0 2372
# 1 82140

# %%
def is_female(row):
    gen = row.borrower_gender
    if gen == "F":
        return 1
    else:
        return 0

dframe['borrower_gender'] = dframe.apply(is_female, axis = 1)

for it, dat in dframe.groupby("borrower_gender"):
    print it, len(dat)
# Out:
# 0 21036
# 1 63476

# %%
dframe.iloc[:6,:15]
# Out:
#             name  status  funded_amount  paid_amount  text_length  \
# id
# 3254       Noemí       1            200          200      1482.00
# 7350    Victoria       1            375          375      1923.00
# 11446       Thuy       1             75           75       517.00
# 15542  Guadalupe       1           1200         1200       851.53
# 19638    Dilfuza       1            400          400       851.53
# 27831      Jesse       1            650          650       551.00
#
#              sector  delinquent     country  partner_id  loan_amount  \
# id
# 3254       Services           0      Mexico          16          200
# 7350         Retail           0     Ecuador           7          375
# 11446        Retail           0     Vietnam          41           75
# 15542  Construction           0      Mexico          18         1200
# 19638        Retail           0  Tajikistan          47          400
# 27831          Food           0       Samoa          15          650
#
#        lender_count  bonus_credit_elig  num_borrowers  borrower_gender  \
# id
# 3254              6                  0              1                1
# 7350             10                  0              1                1
# 11446             1                  0              1                1
# 15542            37                  1              1                1
# 19638            11                  0              1                1
# 27831            26                  0              1                1
#
#        partner_loss_liable
# id
# 3254                     1
# 7350                     1
# 11446                    1
# 15542                    1
# 19638                    1
# 27831                    1

# %%
#should we have a column binary for each country
# // visualize default/fund rate for each country -- suspect that ppl would be less like to fund nigeria
con_list = []
for it, dat in dframe.groupby("country"):
    con_list.append(it.strip())

#print con_list
asia = ["Afghanistan","Armenia","Azerbaijan","Cambodia","Georgia","Indonesia","Iraq","Israel","Jordan","Kyrgyzstan","Lebanon","Moldova","Mongolia","Nepal","Pakistan","Palestine","Philippines","Samoa","Sri Lanka","Tajikistan","Turkey","Vietnam","Yemen"]
africa = ["Benin","Burkina Faso","Burundi","Cameroon","Congo (Dem. Rep.)","Congo (Rep.)","Cote D'Ivoire","Ghana","Kenya","Liberia","Mali","Mozambique","Nigeria","Rwanda","Senegal","Sierra Leone","South Africa","South Sudan","Tanzania","Togo","Uganda","Zimbabwe"]
latin_america = ["Bolivia","Colombia","Chile","Costa Rica","Dominican Republic","Ecuador","El Salvador","Guatemala","Haiti","Honduras","Mexico","Nicaragua","Paraguay","Peru"]
europe = ["Bosnia and Herzegovina","Bulgaria","Ukraine"]
north_america = ["United States"]
# Out:
# ['Afghanistan', 'Armenia', 'Azerbaijan', 'Benin', 'Bolivia', 'Bosnia and Herzegovina', 'Bulgaria', 'Burkina Faso', 'Burundi', 'Cambodia', 'Cameroon', 'Chile', 'Colombia', 'Congo (Dem. Rep.)', 'Congo (Rep.)', 'Costa Rica', "Cote D'Ivoire", 'Dominican Republic', 'Ecuador', 'El Salvador', 'Georgia', 'Ghana', 'Guatemala', 'Haiti', 'Honduras', 'Indonesia', 'Iraq', 'Israel', 'Jordan', 'Kenya', 'Kyrgyzstan', 'Lebanon', 'Liberia', 'Mali', 'Mexico', 'Moldova', 'Mongolia', 'Mozambique', 'Nepal', 'Nicaragua', 'Nigeria', 'Pakistan', 'Palestine', 'Paraguay', 'Peru', 'Philippines', 'Rwanda', 'Samoa', 'Senegal', 'Sierra Leone', 'South Africa', 'South Sudan', 'Sri Lanka', 'Tajikistan', 'Tanzania', 'Togo', 'Turkey', 'Uganda', 'Ukraine', 'United States', 'Vietnam', 'Yemen', 'Zimbabwe']

# %%
def continent(row):
    con = row.country.strip()
    if con in africa:
        return 'africa'
    elif con in asia:
        return 'asia'
    elif con in europe:
        return 'europe'
    elif con in latin_america:
        return 'latin_america'
    elif con in north_america:
        return 'north_america'

dframe.insert(8, "continent", '')
dframe['continent'] = dframe.apply(continent, axis = 1)

for it, dat in dframe.groupby("continent"):
    print it, len(dat)
# Out:
# africa 24672
# asia 31546
# europe 821
# latin_america 27370
# north_america 103

# %%
dframe.iloc[:6,:15]
# Out:
#             name  status  funded_amount  paid_amount  text_length  \
# id
# 3254       Noemí       1            200          200      1482.00
# 7350    Victoria       1            375          375      1923.00
# 11446       Thuy       1             75           75       517.00
# 15542  Guadalupe       1           1200         1200       851.53
# 19638    Dilfuza       1            400          400       851.53
# 27831      Jesse       1            650          650       551.00
#
#              sector  delinquent     country      continent  partner_id  \
# id
# 3254       Services           0      Mexico  latin_america          16
# 7350         Retail           0     Ecuador  latin_america           7
# 11446        Retail           0     Vietnam           asia          41
# 15542  Construction           0      Mexico  latin_america          18
# 19638        Retail           0  Tajikistan           asia          47
# 27831          Food           0       Samoa           asia          15
#
#        loan_amount  lender_count  bonus_credit_elig  num_borrowers  \
# id
# 3254           200             6                  0              1
# 7350           375            10                  0              1
# 11446           75             1                  0              1
# 15542         1200            37                  1              1
# 19638          400            11                  0              1
# 27831          650            26                  0              1
#
#        borrower_gender
# id
# 3254                 1
# 7350                 1
# 11446                1
# 15542                1
# 19638                1
# 27831                1

# %%
list1 = dframe.columns.tolist()
list1[19] = 'pactive'
dframe.columns = list1

# %%
dframe.columns
# Out:
# Index([u'name', u'status', u'funded_amount', u'paid_amount', u'text_length', u'sector', u'delinquent', u'country', u'continent', u'partner_id', u'loan_amount', u'lender_count', u'bonus_credit_elig', u'num_borrowers', u'borrower_gender', u'partner_loss_liable', u'days_fundraising', u'days_late', u'translator', u'pactive', u'prating', u'pdays_as_member', u'pdelinquency_rate', u'pdefault_rate', u'ptotal_amount_raised', u'ploans_posted', u'pcharges_FI', u'pALSPCI', u'ploans_at_risk_rate', u'pforex_loss_rate'], dtype='object')

# %%
#str(dframe.columns.tolist())
y, X = dmatrices('status ~ text_length + C(sector) + delinquent + C(continent) + loan_amount + lender_count + bonus_credit_elig + num_borrowers + \
                 borrower_gender + partner_loss_liable + days_fundraising + days_late + translator + pactive + prating + pdays_as_member + pdelinquency_rate + \
                 pdefault_rate + ptotal_amount_raised + ploans_posted + pcharges_FI + pALSPCI + ploans_at_risk_rate + pforex_loss_rate',
                 dframe, return_type="dataframe")

# %%
dframe.iloc[123:128,:10]
# Out:
#             name  status  funded_amount  paid_amount  text_length  \
# id
# 146756     Maria       1           1050         1050          930
# 150884     Maria       1            150          150          590
# 155033  Sotheary       1            500          500          766
# 159168   Lovelyn       1            275          275         1245
# 163311    Gloria       1            300          300         1062
#
#              sector  delinquent      country      continent  partner_id
# id
# 146756  Agriculture           0         Peru  latin_america          71
# 150884    Wholesale           0      Bolivia  latin_america          48
# 155033         Arts           0     Cambodia           asia          61
# 159168       Retail           0  Philippines           asia         123
# 163311         Arts           0         Peru  latin_america          71

# %%
#X.iloc[123:128,19:]
#X.info()

# %%
print y.shape, 
y = np.ravel(y)
print y.shape
# Out:
# (84512, 1) (84512L,)

# %%
# evaluate the model by splitting into train and test sets
X_train, X_test, y_train, y_test = cross_validation.train_test_split(X,
                                                                     y,
                                                                     test_size=0.3,
                                                                     random_state=0
                                                                     )
logistic_regr = linear_model.LogisticRegression()
logistic_regr.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, penalty='l2', random_state=None, tol=0.0001)

# %%
# predict class labels for the test set
y_predicted = logistic_regr.predict(X_test)
print y_predicted
# Out:
# [ 1.  1.  1. ...,  1.  1.  1.]

# %%
#prediction probabilities
probs = logistic_regr.predict_proba(X_test)
print probs
# Out:
# [[  4.63352209e-03   9.95366478e-01]
#  [  3.04800259e-04   9.99695200e-01]
#  [  2.49418830e-03   9.97505812e-01]
#  ...,
#  [  1.51533266e-03   9.98484667e-01]
#  [  5.43996127e-04   9.99456004e-01]
#  [  1.12749349e-02   9.88725065e-01]]

# %%
# generate evaluation metrics
print metrics.accuracy_score(y_test, y_predicted)
# Out:
# 0.997278535931

# %%
print metrics.confusion_matrix(y_test, y_predicted)
print metrics.classification_report(y_test, y_predicted)
# Out:
# [[  674    67]
#  [    2 24611]]
#              precision    recall  f1-score   support
#
#         0.0       1.00      0.91      0.95       741
#         1.0       1.00      1.00      1.00     24613
#
# avg / total       1.00      1.00      1.00     25354

# %%
# examine the coefficients
print pd.DataFrame(zip(X.columns, np.transpose(logistic_regr.coef_)))
# Out:
#                                 0                     1
# 0                       Intercept   [9.53467069802e-07]
# 1               C(sector)[T.Arts]   [1.62422565959e-08]
# 2           C(sector)[T.Clothing]    [7.5828476874e-08]
# 3       C(sector)[T.Construction]   [2.34964097243e-08]
# 4          C(sector)[T.Education]    [2.4867531219e-08]
# 5      C(sector)[T.Entertainment]  [-1.64994206661e-08]
# 6               C(sector)[T.Food]   [3.23024753521e-07]
# 7             C(sector)[T.Health]  [-1.41564764029e-10]
# 8            C(sector)[T.Housing]   [3.31399846488e-08]
# 9      C(sector)[T.Manufacturing]   [2.68748136712e-08]
# 10      C(sector)[T.Personal Use]  [-1.25537000969e-08]
# 11            C(sector)[T.Retail]   [2.59537539464e-07]
# 12          C(sector)[T.Services]   [5.47942857111e-08]
# 13    C(sector)[T.Transportation]   [1.88156242523e-08]
# 14         C(sector)[T.Wholesale]   [5.80677786185e-09]
# 15           C(continent)[T.asia]   [1.07597347991e-06]
# 16         C(continent)[T.europe]   [7.49039906869e-08]
# 17  C(continent)[T.latin_america]    [2.8820640145e-07]
# 18  C(continent)[T.north_america]  [-3.00756066831e-08]
# 19                    text_length   [0.000487325893483]
# 20                     delinquent  [-4.55156694774e-06]
# 21                    loan_amount   [0.000173027242637]
# 22                   lender_count    [3.8318908793e-06]
# 23              bonus_credit_elig   [4.65687020104e-07]
# 24                  num_borrowers    [1.1315373213e-06]
# 25                borrower_gender   [1.12883461652e-06]
# 26            partner_loss_liable     [1.430213207e-06]
# 27               days_fundraising   [1.48173819278e-07]
# 28                      days_late   [-0.00573782744199]
# 29                     translator   [4.24126628376e-07]
# 30                        pactive   [1.04955966101e-06]
# 31                        prating   [2.33797441389e-06]
# 32                pdays_as_member    [0.00171084728705]
# 33              pdelinquency_rate  [-7.19927018969e-06]
# 34                  pdefault_rate  [-3.63759385406e-05]
# 35           ptotal_amount_raised   [1.13817930289e-07]
# 36                  ploans_posted   [4.77669292752e-05]
# 37                    pcharges_FI   [9.53467069802e-07]
# 38                        pALSPCI   [3.75491614501e-06]
# 39            ploans_at_risk_rate  [-3.26643030326e-06]
# 40               pforex_loss_rate   [6.99611720724e-07]
