# %%
import os
import json
import time
import requests
import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
from pandas import Series, DataFrame
# %matplotlib inline

# %%
c1 = ["id","name","status","funded_amount","basket_amount","paid_amount","activity","sector","themes","use","delinquent"]
c2 = ["country_code","country","town","partner_id","posted_date","planned_expire_date","loan_amount","lender_count","forex_loss"]
c3 = ["bonus_credit_elig","tags","num_borrowers","borrower_gender","disbursal_date","disbursal_currency","disbursal_amount"]
c4 = ["repayment_interval","repayment_term","terms_loan_amount","funded_date","paid_date","translator"]

columns = c1+c2+c3+c4

data_matrix = np.zeros((89492,len(columns)), dtype='S50')

files = os.listdir("loans")
idx = 0

for f in files:
    f_data = open("loans/" + f)
    json_data = f_data.read()

    data = json.loads(json_data)
    loans = data["loans"]
    
    for loan in loans:
        data_matrix[idx][0] = loan["id"]
        data_matrix[idx][1] = loan["name"].encode('utf8')
        data_matrix[idx][2] = loan["status"]
        data_matrix[idx][3] = loan["funded_amount"]
        data_matrix[idx][4] = loan["basket_amount"]
        data_matrix[idx][5] = loan["paid_amount"]
        data_matrix[idx][6] = loan["activity"]
        data_matrix[idx][7] = loan["sector"]
        data_matrix[idx][8] = str(loan["themes"])
        data_matrix[idx][9] = loan["use"].encode('utf8')
        data_matrix[idx][10] = loan["delinquent"]
        data_matrix[idx][11] = loan["location"]["country_code"]
        data_matrix[idx][12] = loan["location"]["country"]
        town = loan["location"]["town"]
        if town is not None:
            data_matrix[idx][13] = loan["location"]["town"].encode('utf8')
        data_matrix[idx][14] = loan["partner_id"]
        data_matrix[idx][15] = loan["posted_date"]
        data_matrix[idx][16] = loan["planned_expiration_date"]
        data_matrix[idx][17] = loan["loan_amount"]
        data_matrix[idx][18] = loan["lender_count"]
        data_matrix[idx][19] = loan["currency_exchange_loss_amount"]
        data_matrix[idx][20] = loan["bonus_credit_eligibility"]
        data_matrix[idx][21] = str(loan["tags"])
        data_matrix[idx][22] = len(loan["borrowers"])
        data_matrix[idx][23] = loan["borrowers"][0]["gender"] #forst one
        data_matrix[idx][24] = loan["terms"]["disbursal_date"] 
        data_matrix[idx][25] = loan["terms"]["disbursal_currency"] 
        data_matrix[idx][26] = loan["terms"]["disbursal_amount"]
        data_matrix[idx][27] = loan["terms"]["repayment_interval"] 
        data_matrix[idx][28] = loan["terms"]["repayment_term"] 
        data_matrix[idx][29] = loan["terms"]["loan_amount"]
        data_matrix[idx][30] = loan["funded_date"]
        data_matrix[idx][31] = loan["paid_date"]
        data_matrix[idx][32] = (loan["translator"] is not None) # exists?
        
        idx += 1
    
    f_data.close()

data_matrix[0]
# Out:
# array(['3254', 'Noem\xc3\xad', 'paid', '200', 'None', '200', 'Sewing',
#        'Services', 'None', 'Purchase merchandise', 'None', 'MX', 'Mexico',
#        'Monclova,Coahuila', '16', '2006-12-31T02:32:42Z', 'None', '200',
#        '6', 'None', 'False', '[]', '1', 'F', '2007-01-14T05:29:18Z', 'USD',
#        '200', 'Monthly', '6', '200', '2006-12-31T05:29:18Z',
#        '2007-06-04T09:15:29Z', 'False'],
#       dtype='|S50')

# %%
dframe = pd.DataFrame(data_matrix, columns=columns)

# %%
#dframe.funded_amount = dframe['funded_amount'].astype(float)
#dframe.loan_amount = dframe['loan_amount'].astype(float)
#dframe.lender_count = dframe['lender_count'].astype(float)
dframe.num_borrowers = dframe['num_borrowers'].astype(float)
#dframe = dframe.drop(dframe.index[[89491,99997]])
#dframe.iloc[89491,0]
dframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 89492 entries, 0 to 89491
# Data columns (total 33 columns):
# id                     89492 non-null object
# name                   89492 non-null object
# status                 89492 non-null object
# funded_amount          89492 non-null float64
# basket_amount          89492 non-null object
# paid_amount            89492 non-null object
# activity               89492 non-null object
# sector                 89492 non-null object
# themes                 89492 non-null object
# use                    89492 non-null object
# delinquent             89492 non-null object
# country_code           89492 non-null object
# country                89492 non-null object
# town                   89492 non-null object
# partner_id             89492 non-null object
# posted_date            89492 non-null object
# planned_expire_date    89492 non-null object
# loan_amount            89492 non-null float64
# lender_count           89492 non-null float64
# forex_loss             89492 non-null object
# bonus_credit_elig      89492 non-null object
# tags                   89492 non-null object
# num_borrowers          89492 non-null float64
# borrower_gender        89492 non-null object
# disbursal_date         89492 non-null object
# disbursal_currency     89492 non-null object
# disbursal_amount       89492 non-null object
# repayment_interval     89492 non-null object
# repayment_term         89492 non-null object
# terms_loan_amount      89492 non-null object
# funded_date            89492 non-null object
# paid_date              89492 non-null object
# translator             89492 non-null object
# dtypes: float64(4), object(29)
# memory usage: 23.2+ MB

# %%
dframe.iloc[0:10,10:23]
# Out:
#   delinquent country_code     country                  town partner_id  \
# 0       None           MX      Mexico     Monclova,Coahuila         16
# 1       None           EC     Ecuador             Guayaquil          7
# 2       None           VN     Vietnam  Duc Linh, Binh Thuan         41
# 3       None           MX      Mexico          Nuevo Laredo         18
# 4       None           TJ  Tajikistan             Kairakkum         47
# 5       None           TZ    Tanzania                               90
# 6       None           WS       Samoa           Samatau Fou         15
# 7       None           AZ  Azerbaijan               Imishli         56
# 8       None           UG      Uganda                 Njeru         65
# 9       None           MX      Mexico               Chamula         51
#
#             posted_date planned_expire_date  loan_amount  lender_count  \
# 0  2006-12-31T02:32:42Z                None          200             6
# 1  2007-04-07T16:12:51Z                None          375            10
# 2  2007-06-06T02:45:10Z                None           75             1
# 3  2007-08-15T23:34:12Z                None         1200            37
# 4  2007-09-28T22:15:04Z                None          400            11
# 5  2007-11-20T13:35:05Z                None          450            13
# 6  2007-12-19T21:40:10Z                None          650            26
# 7  2008-02-01T17:20:07Z                None         1100            28
# 8  2008-06-10T06:40:14Z                None         1125            29
# 9  2008-03-08T15:00:06Z                None         1775            23
#
#   forex_loss bonus_credit_elig tags  num_borrowers
# 0       None             False   []              1
# 1       None             False   []              1
# 2       None             False   []              1
# 3       None              True   []              1
# 4       None             False   []              1
# 5       None             False   []              1
# 6       None             False   []              1
# 7       None              True   []              1
# 8       None              True   []              5
# 9       None             False   []              5

# %%
for gen, gen_data in dframe.groupby('borrower_gender'):
    print gen
    print len(gen_data)
# Out:
# F
# 67144
# M
# 22348

# %%
# TODO histogram
for stat, stat_data in dframe.groupby('status'):
    print stat
    print len(stat_data)
# Out:
# 1
# defaulted
# 2373
# deleted
# 616
# expired
# 53
# in_repayment
# 10
# inactive
# 567
# inactive_expired
# 2631
# issue
# 91
# paid
# 82192
# refunded
# 956
# reviewed
# 2

# %%
#for amt, stat_data in dframe.groupby('status'):
ls = [1.0,3.0,5.0,4.0,5.0,4.0,1.0]
amounts = dframe.loan_amount
amt = amounts.tolist()
ls[0:3]
#amounts.plot(kind="hist")
#plt.hist(amt,bins=20)

#DataFrame.hist(dframe,column='loan_amount', bins=30)
#dframe.loan_amount.max()
# Out:
# (array([  8.60180000e+04,   3.37500000e+03,   6.10000000e+01,
#           2.10000000e+01,   1.20000000e+01,   1.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   1.00000000e+00,
#           1.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   1.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   1.00000000e+00]),
#  array([  2.50000000e+01,   2.51375000e+03,   5.00250000e+03,
#           7.49125000e+03,   9.98000000e+03,   1.24687500e+04,
#           1.49575000e+04,   1.74462500e+04,   1.99350000e+04,
#           2.24237500e+04,   2.49125000e+04,   2.74012500e+04,
#           2.98900000e+04,   3.23787500e+04,   3.48675000e+04,
#           3.73562500e+04,   3.98450000e+04,   4.23337500e+04,
#           4.48225000e+04,   4.73112500e+04,   4.98000000e+04]),
#  <a list of 20 Patch objects>)
